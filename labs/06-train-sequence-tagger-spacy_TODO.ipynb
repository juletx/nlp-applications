# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# TODO install the language modules of your choice following the https://spacy.io/usage

# !python -m spacy download en_core_web_sm
#!python -m spacy download en_core_web_md
#!python -m spacy download en_core_web_lg
# Out:
# ...
#      |████████████████████████████████| 12.0 MB 17.5 MB/s
# ...
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')

# %%
# !mkdir /content/drive/My\ Drive/Colab\ Notebooks/2022-ILTAPP/datasets/spacy_ner_data
# !python3 -m spacy convert "/content/drive/My Drive/Colab Notebooks/2022-ILTAPP/datasets/ner/eu-test.tsv" /content/drive/My\ Drive/Colab\ Notebooks/2022-ILTAPP/datasets/spacy_ner_data -c ner
# !python3 -m spacy convert "/content/drive/My Drive/Colab Notebooks/2022-ILTAPP/datasets/ner/eu-train.tsv" /content/drive/My\ Drive/Colab\ Notebooks/2022-ILTAPP/datasets/spacy_ner_data -c ner
# Out:
# mkdir: cannot create directory ‘/content/drive/My Drive/Colab Notebooks/2022-ILTAPP/datasets/spacy_ner_data’: File exists
# ℹ Auto-detected token-per-line NER format
# ℹ Grouping every 1 sentences into a document.
# ⚠ To generate better training data, you may want to group sentences
# into documents with `-n 10`.
# ✔ Generated output file (842 documents): /content/drive/My Drive/Colab
# Notebooks/2022-ILTAPP/datasets/spacy_ner_data/eu-test.json
# ℹ Auto-detected token-per-line NER format
# ℹ Grouping every 1 sentences into a document.
# ⚠ To generate better training data, you may want to group sentences
# into documents with `-n 10`.
# ✔ Generated output file (2552 documents): /content/drive/My Drive/Colab
# Notebooks/2022-ILTAPP/datasets/spacy_ner_data/eu-train.json

# %%
# !echo "BEFORE : (/content/drive/My Drive/Colab Notebooks/2022-ILTAPP/datasets/ner/eu-test.tsv)"
# !head "/content/drive/My Drive/Colab Notebooks/2022-ILTAPP/datasets/ner/eu-test.tsv" -n 20
# !echo "\nAFTER : (/content/drive/My Drive/Colab Notebooks/2022-ILTAPP/datasets/ner/eu-train.json)"
# !head "/content/drive/My Drive/Colab Notebooks/2022-ILTAPP/datasets/ner/eu-train.tsv" -n 20
# Out:
# BEFORE : (/content/drive/My Drive/Colab Notebooks/2022-ILTAPP/datasets/ner/eu-test.tsv)
# Garikoitz	B-PER
# Plazaola	I-PER
# *	O
# Eguzki-ko	B-ORG
# kidea	O
# *	O
# «	O
# Apaingarri	O
# birziklagarriak	O
# bultzatu	O
# behar	O
# dira	O
# »	O
# Gabonetako	B-MISC
# apainduren	O
# inguruan	O
# hitz	O
# egin	O
# dugu	O
# ,	O
# \nAFTER : (/content/drive/My Drive/Colab Notebooks/2022-ILTAPP/datasets/ner/eu-train.json)
# Greba	O
# orokorrera	O
# deitu	O
# du	O
# EHk	B-ORG
# 27rako	O
# ,	O
# presoen	O
# Euskal	O
# Herriratzea	O
# eskatzeko	O
# Euskal	O
# gizartearen	O
# gehiengoaren	O
# borondatea	O
# errespeta	O
# dezatela	O
# exijituko	O
# zaie	O
# madrili	B-ORG

# %%
# !python3 -m spacy train en /content/drive/My\ Drive/Colab\ Notebooks/2022-ILTAPP/resources/spacy-ner-model /content/drive/My\ Drive/Colab Notebooks/2022-ILTAPP/datasets/spacy_ner_data/eu-train.json /content/drive/My\ Drive/Colab\ Notebooks/2022-ILTAPP/datasets/spacy_ner_data/eu-test.json -p ner
# Out:
# usage: spacy train [-h] [-rt None] [-b None] [-p tagger,parser,ner] [-R]
#                    [-v None] [-cw 96] [-cd 4] [-cW 1] [-cP 3] [-chr] [-lstm 0]
#                    [-er 2000] [-n 30] [-ne None] [-ns 0] [-g -1] [-V 0.0.0]
#                    [-m None] [-t2v None] [-pt ''] [-et ''] [-nl 0.0]
#                    [-ovl 0.0] [-bw ''] [-G] [-T] [-TML] [-ta bow] [-tpl None]
#                    [-tm None] [-VV] [-D]
#                    lang output_path train_path dev_path
# spacy train: error: unrecognized arguments: /content/drive/My Drive/Colab Notebooks/2022-ILTAPP/datasets/spacy_ner_data/eu-test.json

# %%
#create a folder to store the output and visualizations.
# !python3 -m spacy evaluate /content/drive/My\ Drive/Colab\ Notebooks/2022-ILTAPP/resources/spacy-ner-model/model-best /content/drive/My\ Drive/Colab\ Notebooks/2022-ILTAPP/datasets/spacy_ner_data/eu-test.json -dp /content/drive/My\ Drive/Colab\ Notebooks/2022-ILTAPP/datasets/spacy_ner_data
# Out:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.7/dist-packages/spacy/__main__.py", line 33, in <module>
#     plac.call(commands[command], sys.argv[1:])
#   File "/usr/local/lib/python3.7/dist-packages/plac_core.py", line 367, in call
#     cmd, result = parser.consume(arglist)
#   File "/usr/local/lib/python3.7/dist-packages/plac_core.py", line 232, in consume
#     return cmd, self.func(*(args + varargs + extraopts), **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/spacy/cli/evaluate.py", line 46, in evaluate
#     nlp = util.load_model(model)
#   File "/usr/local/lib/python3.7/dist-packages/spacy/util.py", line 169, in load_model
#     raise IOError(Errors.E050.format(name=name))
# ...

# %%
import spacy
from spacy import displacy

ner_tagger = spacy.load("/content/drive/My Drive/Colab Notebooks/2022-ILTAPP/resources/spacy-ner-model/model-best")
doc = ner_tagger("Jeroen Dijsselbloem Eurotaldeko presidentearekin egin du bilera Varufakisek, eta haren aurrean nabarmendu du Greziako Gobernua 'egungo erreskate plana onartzen ez duen programa batengatik' aukeratu zutela herritarrek. Hala ere, azaldu du gobernuaren asmoa da Europako kidekin elkarlanean aritzea dela.")
displacy.render(doc, style='ent', jupyter=True, options={'distance': 90})
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-29-870a58c67c98> in <module>()
#       2 from spacy import displacy
#       3
# ----> 4 ner_tagger = spacy.load("/content/drive/My Drive/Colab Notebooks/2022-ILTAPP/resources/spacy-ner-model/model-best")
#       5 doc = ner_tagger("Jeroen Dijsselbloem Eurotaldeko presidentearekin egin du bilera Varufakisek, eta haren aurrean nabarmendu du Greziako Gobernua 'egungo erreskate plana onartzen ez duen programa batengatik' aukeratu zutela herritarrek. Hala ere, azaldu du gobernuaren asmoa da Europako kidekin elkarlanean aritzea dela.")
#       6 displacy.render(doc, style='ent', jupyter=True, options={'distance': 90})
#
# /usr/local/lib/python3.7/dist-packages/spacy/__init__.py in load(name, **overrides)
#      28     if depr_path not in (True, False, None):
# ...
